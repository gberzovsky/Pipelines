# %%
from pipeline import Pipeline
pipeline = Pipeline

# %%
import pandas as pd
df = pd.read_json('hn_stories_2014.json')
df
# Out:
#                                                   stories
# 0       {'story_text': '', 'created_at': '2014-05-29T0...
# 1       {'story_text': '', 'created_at': '2014-05-29T0...
# 2       {'story_text': '', 'created_at': '2014-05-29T0...
# 3       {'story_text': '', 'created_at': '2014-05-29T0...
# 4       {'story_text': '', 'created_at': '2014-05-29T0...
# ...                                                   ...
# 107499  {'story_text': 'Judging from the numerous othe...
# 107500  {'story_text': None, 'created_at': '2014-01-01...
# 107501  {'story_text': 'https:&#x2F;&#x2F;fundraising....
# 107502  {'story_text': None, 'created_at': '2014-01-01...
# 107503  {'story_text': '', 'created_at': '2014-01-01T0...
#
# [107504 rows x 1 columns]

# %%
#print(df.to_string())

# %%
df['stories']
# Out:
# 0         {'story_text': '', 'created_at': '2014-05-29T0...
# 1         {'story_text': '', 'created_at': '2014-05-29T0...
# 2         {'story_text': '', 'created_at': '2014-05-29T0...
# 3         {'story_text': '', 'created_at': '2014-05-29T0...
# 4         {'story_text': '', 'created_at': '2014-05-29T0...
#                                 ...
# 107499    {'story_text': 'Judging from the numerous othe...
# 107500    {'story_text': None, 'created_at': '2014-01-01...
# 107501    {'story_text': 'https:&#x2F;&#x2F;fundraising....
# 107502    {'story_text': None, 'created_at': '2014-01-01...
# 107503    {'story_text': '', 'created_at': '2014-01-01T0...
# Name: stories, Length: 107504, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107504 entries, 0 to 107503
# Data columns (total 1 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   stories  107504 non-null  object
# dtypes: object(1)
# memory usage: 840.0+ KB

# %%
#df.describe()

# %%
df.memory_usage()
# Out:
# Index         128
# stories    860032
# dtype: int64

# %%
df.head()
# Out:
#                                              stories
# 0  {'story_text': '', 'created_at': '2014-05-29T0...
# 1  {'story_text': '', 'created_at': '2014-05-29T0...
# 2  {'story_text': '', 'created_at': '2014-05-29T0...
# 3  {'story_text': '', 'created_at': '2014-05-29T0...
# 4  {'story_text': '', 'created_at': '2014-05-29T0...

# %%
df.dtypes
# Out:
# stories    object
# dtype: object

# %%
#import json
#json_dict = json.load('hn_stories_2014.json')

# %%
import json
  
# Opening JSON file
f = open('hn_stories_2014.json',)
  
# returns JSON object as 
# a dictionary
data = json.load(f)
df=pd.json_normalize(data, record_path=['stories'])
  
# Iterating through the json
# list
#for i in data['stories']:
   # print(i)
  
# Closing file
#f.close()
# Out:
#                                                story_text  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 107499  Judging from the numerous other threads it see...
# 107500                                               None
# 107501    https:&#x2F;&#x2F;fundraising.mozilla.org&#x2F;
# 107502                                               None
# 107503
#
#                   created_at story_title  story_id comment_text  created_at_i  \
# 0       2014-05-29T08:25:40Z        None       NaN         None    1401351940
# 1       2014-05-29T08:23:46Z        None       NaN         None    1401351826
# 2       2014-05-29T08:21:56Z        None       NaN         None    1401351716
# 3       2014-05-29T08:18:42Z        None       NaN         None    1401351522
# 4       2014-05-29T08:17:30Z        None       NaN         None    1401351450
# ...                      ...         ...       ...          ...           ...
# ...

# %%
def open_json(url,data_list):
    f = open(url)
    data = json.load(f)
    df=pd.json_normalize(data, record_path=[data_list]) 
    return df

# %%
open_json('hn_stories_2014.json', 'stories')
# Out:
#                                                story_text  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 107499  Judging from the numerous other threads it see...
# 107500                                               None
# 107501    https:&#x2F;&#x2F;fundraising.mozilla.org&#x2F;
# 107502                                               None
# 107503
#
#                   created_at story_title  story_id comment_text  created_at_i  \
# 0       2014-05-29T08:25:40Z        None       NaN         None    1401351940
# 1       2014-05-29T08:23:46Z        None       NaN         None    1401351826
# 2       2014-05-29T08:21:56Z        None       NaN         None    1401351716
# 3       2014-05-29T08:18:42Z        None       NaN         None    1401351522
# 4       2014-05-29T08:17:30Z        None       NaN         None    1401351450
# ...                      ...         ...       ...          ...           ...
# ...

# %%
df.shape
# Out:
# (107504, 27)

# %%
columns=pd.set_option('display.max_columns', None)

# %%
df.columns
# Out:
# Index(['story_text', 'created_at', 'story_title', 'story_id', 'comment_text',
#        'created_at_i', 'url', 'parent_id', 'objectID', 'author', 'points',
#        'title', '_tags', 'num_comments', 'story_url',
#        '_highlightResult.story_text.matchedWords',
#        '_highlightResult.story_text.value',
#        '_highlightResult.story_text.matchLevel',
#        '_highlightResult.author.matchedWords', '_highlightResult.author.value',
#        '_highlightResult.author.matchLevel',
#        '_highlightResult.url.matchedWords', '_highlightResult.url.value',
#        '_highlightResult.url.matchLevel',
#        '_highlightResult.title.matchedWords', '_highlightResult.title.value',
#        '_highlightResult.title.matchLevel'],
#       dtype='object')

# %%
df['points']
# Out:
# 0         1
# 1         1
# 2         2
# 3         1
# 4         1
#          ..
# 107499    8
# 107500    1
# 107501    1
# 107502    2
# 107503    1
# Name: points, Length: 107504, dtype: int64

# %%
df['points'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         1
# 1         1
# 2         2
# 3         1
# 4         1
#          ..
# 107499    8
# 107500    1
# 107501    1
# 107502    2
# 107503    1
# Name: points, Length: 107504, dtype: int64>

# %%
df['num_comments']
# Out:
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
#           ..
# 107499    13
# 107500     0
# 107501     0
# 107502     0
# 107503     0
# Name: num_comments, Length: 107504, dtype: int64

# %%
max_points=df['points'] > 50
max_points
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 107499    False
# 107500    False
# 107501    False
# 107502    False
# 107503    False
# Name: points, Length: 107504, dtype: bool

# %%
def max_point(df, col):
    max_points=df[col] > 50
    return max_points

# %%
max_point(df, 'points')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 107499    False
# 107500    False
# 107501    False
# 107502    False
# 107503    False
# Name: points, Length: 107504, dtype: bool

# %%
df.head()
# Out:
#   story_text            created_at story_title  story_id comment_text  \
# 0             2014-05-29T08:25:40Z        None       NaN         None
# 1             2014-05-29T08:23:46Z        None       NaN         None
# 2             2014-05-29T08:21:56Z        None       NaN         None
# 3             2014-05-29T08:18:42Z        None       NaN         None
# 4             2014-05-29T08:17:30Z        None       NaN         None
#
#    created_at_i                                                url  parent_id  \
# 0    1401351940                    https://duckduckgo.com/settings        NaN
# 1    1401351826  http://bits.blogs.nytimes.com/2014/05/28/makin...        NaN
# 2    1401351716      http://www.bbc.co.uk/news/technology-27617079        NaN
# 3    1401351522  http://nomination.younggloballeaders.org/nomin...        NaN
# 4    1401351450                                  https://blooki.st        NaN
#
#   objectID     author  points  \
# 0  7815290     TuxLyn       1
# ...

# %%
df['story_text'].value_counts(dropna=False)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 85101
# ...

# %%
#THE COLUMNS WE WANT TO USE:
# created_at: A timestamp of the story's creation time.
# created_at_i: A unix epoch timestamp.
# url: The URL of the story link.
# objectID: The ID of the story.
# author: The story's author (username on HN).
# points: The number of upvotes the story had.
# title: The headline of the post.
# num_comments: The number of a comments a post has.

# %%
#The plan of action is as follows:  The goal is = We need to find the top 100 keywords of Hacker News posts.
#First we check out the columns to see which ones we logically will need for this.  We will definitely need something with a number, an 
#amount so that is probably the points, we will probably need the comments amount because that obviously indicates popularity, the
#basic info of the story including author, title etc.  We will filter out the points to more than a certain amount to indicate popularity
#then we will see.....

# %%
df['created_at']
# Out:
# 0         2014-05-29T08:25:40Z
# 1         2014-05-29T08:23:46Z
# 2         2014-05-29T08:21:56Z
# 3         2014-05-29T08:18:42Z
# 4         2014-05-29T08:17:30Z
#                   ...
# 107499    2014-01-01T00:17:03Z
# 107500    2014-01-01T00:11:06Z
# 107501    2014-01-01T00:06:59Z
# 107502    2014-01-01T00:04:31Z
# 107503    2014-01-01T00:01:00Z
# Name: created_at, Length: 107504, dtype: object

# %%
# new_df = df.drop('story_text', axis=1)
# new_df = df.drop('story_title', axis=1)
# new_df = df.drop('story_id', axis=1)
# new_df = df.drop('comment_text', axis=1)
# new_df = df.drop('parent_id', axis=1)

# new_df = df.drop('story_url', axis=1)
# new_df = df.drop('_highlightResult.story_text.value', axis=1)

# new_df = df.drop('_highlightResult.story_text.matchLevel', axis=1)
# new_df = df.drop('_highlightResult.author.matchedWords', axis=1)
# new_df = df.drop('_highlightResult.author.value', axis=1)

# %%
new_df = df[['created_at','created_at_i','url','objectID','author','points', 'title', 'num_comments']]
new_df
# Out:
#                   created_at  created_at_i  \
# 0       2014-05-29T08:25:40Z    1401351940
# 1       2014-05-29T08:23:46Z    1401351826
# 2       2014-05-29T08:21:56Z    1401351716
# 3       2014-05-29T08:18:42Z    1401351522
# 4       2014-05-29T08:17:30Z    1401351450
# ...                      ...           ...
# 107499  2014-01-01T00:17:03Z    1388535423
# 107500  2014-01-01T00:11:06Z    1388535066
# 107501  2014-01-01T00:06:59Z    1388534819
# 107502  2014-01-01T00:04:31Z    1388534671
# 107503  2014-01-01T00:01:00Z    1388534460
#
#                                                       url objectID  \
# 0                         https://duckduckgo.com/settings  7815290
# 1       http://bits.blogs.nytimes.com/2014/05/28/makin...  7815285
# 2           http://www.bbc.co.uk/news/technology-27617079  7815279
# 3       http://nomination.younggloballeaders.org/nomin...  7815274
# 4                                       https://blooki.st  7815273
# ...

# %%
def create_new_df(df, col_list):
    new_df = df[col_list]
    return new_df

# %%
max_points=new_df[new_df['points'] > 50]

# %%
max_points
# Out:
#                   created_at  created_at_i  \
# 70      2014-05-29T04:27:42Z    1401337662
# 76      2014-05-29T03:51:01Z    1401335461
# 91      2014-05-29T02:59:12Z    1401332352
# 124     2014-05-29T01:36:05Z    1401327365
# 137     2014-05-29T00:59:30Z    1401325170
# ...                      ...           ...
# 107436  2014-01-01T04:42:30Z    1388551350
# 107448  2014-01-01T03:34:45Z    1388547285
# 107451  2014-01-01T03:25:02Z    1388546702
# 107455  2014-01-01T03:17:00Z    1388546220
# 107457  2014-01-01T03:07:05Z    1388545625
#
#                                                       url objectID  \
# 70      http://krebsonsecurity.com/2014/05/true-goodby...  7814725
# 76      http://projects.aljazeera.com/2014/portrait-of...  7814608
# 91      http://www.damninteresting.com/absolute-zero-i...  7814466
# 124     http://priceonomics.com/joshua-norton-emperor-...  7814140
# 137     http://www.nytimes.com/2014/05/29/technology/p...  7814005
# ...

# %%
def filter_stories(df, col1, col2, col3, string):
    max_points=df[df[col1] > 50]
    one_comment_plus=max_points[max_points[col2]>1]
    filtered_df=one_comment_plus[~one_comment_plus[col3].str.startswith(string)]
    return filtered_df

# %%
filter_stories(new_df, 'points', 'num_comments', 'title', 'Ask HN')
# Out:
#                   created_at  created_at_i  \
# 70      2014-05-29T04:27:42Z    1401337662
# 76      2014-05-29T03:51:01Z    1401335461
# 91      2014-05-29T02:59:12Z    1401332352
# 124     2014-05-29T01:36:05Z    1401327365
# 137     2014-05-29T00:59:30Z    1401325170
# ...                      ...           ...
# 107436  2014-01-01T04:42:30Z    1388551350
# 107448  2014-01-01T03:34:45Z    1388547285
# 107451  2014-01-01T03:25:02Z    1388546702
# 107455  2014-01-01T03:17:00Z    1388546220
# 107457  2014-01-01T03:07:05Z    1388545625
#
#                                                       url objectID  \
# 70      http://krebsonsecurity.com/2014/05/true-goodby...  7814725
# 76      http://projects.aljazeera.com/2014/portrait-of...  7814608
# 91      http://www.damninteresting.com/absolute-zero-i...  7814466
# 124     http://priceonomics.com/joshua-norton-emperor-...  7814140
# 137     http://www.nytimes.com/2014/05/29/technology/p...  7814005
# ...

# %%
one_comment_plus=max_points[max_points['num_comments']>1]

# %%
one_comment_plus
# Out:
#                   created_at  created_at_i  \
# 70      2014-05-29T04:27:42Z    1401337662
# 76      2014-05-29T03:51:01Z    1401335461
# 91      2014-05-29T02:59:12Z    1401332352
# 124     2014-05-29T01:36:05Z    1401327365
# 137     2014-05-29T00:59:30Z    1401325170
# ...                      ...           ...
# 107436  2014-01-01T04:42:30Z    1388551350
# 107448  2014-01-01T03:34:45Z    1388547285
# 107451  2014-01-01T03:25:02Z    1388546702
# 107455  2014-01-01T03:17:00Z    1388546220
# 107457  2014-01-01T03:07:05Z    1388545625
#
#                                                       url objectID  \
# 70      http://krebsonsecurity.com/2014/05/true-goodby...  7814725
# 76      http://projects.aljazeera.com/2014/portrait-of...  7814608
# 91      http://www.damninteresting.com/absolute-zero-i...  7814466
# 124     http://priceonomics.com/joshua-norton-emperor-...  7814140
# 137     http://www.nytimes.com/2014/05/29/technology/p...  7814005
# ...

# %%
df['title']
# Out:
# 0                                       DuckDuckGo Settings
# 1                              Making Twitter Easier to Use
# 2                  London refers Uber app row to High Court
# 3          Young Global Leaders, who should be nominated...
# 4                        Blooki.st goes BETA in a few hours
#                                 ...
# 107499    Ask HN: What would it take for you to switch t...
# 107500                                           Jesus e eu
# 107501    Mozilla end-of-year fundraising jumps from $75...
# 107502                    Introducing Standard Analytics IO
# 107503                          Collection Equality is Hard
# Name: title, Length: 107504, dtype: object

# %%
filtered_df=one_comment_plus[~one_comment_plus['title'].str.startswith("Ask HN")]

# %%
filtered_df
# Out:
#                   created_at  created_at_i  \
# 70      2014-05-29T04:27:42Z    1401337662
# 76      2014-05-29T03:51:01Z    1401335461
# 91      2014-05-29T02:59:12Z    1401332352
# 124     2014-05-29T01:36:05Z    1401327365
# 137     2014-05-29T00:59:30Z    1401325170
# ...                      ...           ...
# 107436  2014-01-01T04:42:30Z    1388551350
# 107448  2014-01-01T03:34:45Z    1388547285
# 107451  2014-01-01T03:25:02Z    1388546702
# 107455  2014-01-01T03:17:00Z    1388546220
# 107457  2014-01-01T03:07:05Z    1388545625
#
#                                                       url objectID  \
# 70      http://krebsonsecurity.com/2014/05/true-goodby...  7814725
# 76      http://projects.aljazeera.com/2014/portrait-of...  7814608
# 91      http://www.damninteresting.com/absolute-zero-i...  7814466
# 124     http://priceonomics.com/joshua-norton-emperor-...  7814140
# 137     http://www.nytimes.com/2014/05/29/technology/p...  7814005
# ...

# %%
filtered_df['title']
# Out:
# 70            True Goodbye: ‘Using TrueCrypt Is Not Secure’
# 76         For Hire: Dedicated Young Man With Down Syndrome
# 91                                            Absolute Zero
# 124             Joshua Norton, Emperor of the United States
# 137          The Soylent Revolution Will Not Be Pleasurable
#                                 ...
# 107436    Fixing E.T. The Extra-Terrestrial for the Atar...
# 107448                                2-Stage Light Gas Gun
# 107451    Court Rules No Suspicion Needed for Laptop Sea...
# 107455    Show HN: Our little bootstrapped startup is po...
# 107457                Snapchat Phone Number Database Leaked
# Name: title, Length: 5978, dtype: object

# %%
filtered_df.to_csv('Hacker_News')

# %%
pd.read_csv('Hacker_News')
# Out:
#       Unnamed: 0            created_at  created_at_i  \
# 0             70  2014-05-29T04:27:42Z    1401337662
# 1             76  2014-05-29T03:51:01Z    1401335461
# 2             91  2014-05-29T02:59:12Z    1401332352
# 3            124  2014-05-29T01:36:05Z    1401327365
# 4            137  2014-05-29T00:59:30Z    1401325170
# ...          ...                   ...           ...
# 5973      107436  2014-01-01T04:42:30Z    1388551350
# 5974      107448  2014-01-01T03:34:45Z    1388547285
# 5975      107451  2014-01-01T03:25:02Z    1388546702
# 5976      107455  2014-01-01T03:17:00Z    1388546220
# 5977      107457  2014-01-01T03:07:05Z    1388545625
#
#                                                     url  objectID  \
# 0     http://krebsonsecurity.com/2014/05/true-goodby...   7814725
# 1     http://projects.aljazeera.com/2014/portrait-of...   7814608
# 2     http://www.damninteresting.com/absolute-zero-i...   7814466
# ...

# %%
#del filtered_df['Unnamed:0']

# %%
#filtered_df = filtered_df.drop('Unnamed: 0', 1)

# %%
clean_df = pd.read_csv('Hacker_News', index_col=0)

# %%
clean_df
# Out:
#                   created_at  created_at_i  \
# 70      2014-05-29T04:27:42Z    1401337662
# 76      2014-05-29T03:51:01Z    1401335461
# 91      2014-05-29T02:59:12Z    1401332352
# 124     2014-05-29T01:36:05Z    1401327365
# 137     2014-05-29T00:59:30Z    1401325170
# ...                      ...           ...
# 107436  2014-01-01T04:42:30Z    1388551350
# 107448  2014-01-01T03:34:45Z    1388547285
# 107451  2014-01-01T03:25:02Z    1388546702
# 107455  2014-01-01T03:17:00Z    1388546220
# 107457  2014-01-01T03:07:05Z    1388545625
#
#                                                       url  objectID  \
# 70      http://krebsonsecurity.com/2014/05/true-goodby...   7814725
# 76      http://projects.aljazeera.com/2014/portrait-of...   7814608
# 91      http://www.damninteresting.com/absolute-zero-i...   7814466
# 124     http://priceonomics.com/joshua-norton-emperor-...   7814140
# 137     http://www.nytimes.com/2014/05/29/technology/p...   7814005
# ...

# %%
clean_df['created_at'] = pd.to_datetime(clean_df['created_at'])

# %%
clean_df
# Out:
#                       created_at  created_at_i  \
# 70     2014-05-29 04:27:42+00:00    1401337662
# 76     2014-05-29 03:51:01+00:00    1401335461
# 91     2014-05-29 02:59:12+00:00    1401332352
# 124    2014-05-29 01:36:05+00:00    1401327365
# 137    2014-05-29 00:59:30+00:00    1401325170
# ...                          ...           ...
# 107436 2014-01-01 04:42:30+00:00    1388551350
# 107448 2014-01-01 03:34:45+00:00    1388547285
# 107451 2014-01-01 03:25:02+00:00    1388546702
# 107455 2014-01-01 03:17:00+00:00    1388546220
# 107457 2014-01-01 03:07:05+00:00    1388545625
#
#                                                       url  objectID  \
# 70      http://krebsonsecurity.com/2014/05/true-goodby...   7814725
# 76      http://projects.aljazeera.com/2014/portrait-of...   7814608
# 91      http://www.damninteresting.com/absolute-zero-i...   7814466
# 124     http://priceonomics.com/joshua-norton-emperor-...   7814140
# ...

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5978 entries, 70 to 107457
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   created_at    5978 non-null   datetime64[ns, UTC]
#  1   created_at_i  5978 non-null   int64
#  2   url           5919 non-null   object
#  3   objectID      5978 non-null   int64
#  4   author        5978 non-null   object
#  5   points        5978 non-null   int64
#  6   title         5978 non-null   object
#  7   num_comments  5978 non-null   int64
# dtypes: datetime64[ns, UTC](1), int64(4), object(3)
# memory usage: 420.3+ KB

# %%
def json_to_csv(df, df2, col1, csv_name):
    df.to_csv(csv_name)
    df2 = pd.read_csv(csv_name, index_col=0)
    df2[col1] = pd.to_datetime(df2[col1])
    return df2

# %%
json_to_csv(filtered_df, clean_df, 'created_at', 'Hacker_News.csv')
# Out:
#                       created_at  created_at_i  \
# 70     2014-05-29 04:27:42+00:00    1401337662
# 76     2014-05-29 03:51:01+00:00    1401335461
# 91     2014-05-29 02:59:12+00:00    1401332352
# 124    2014-05-29 01:36:05+00:00    1401327365
# 137    2014-05-29 00:59:30+00:00    1401325170
# ...                          ...           ...
# 107436 2014-01-01 04:42:30+00:00    1388551350
# 107448 2014-01-01 03:34:45+00:00    1388547285
# 107451 2014-01-01 03:25:02+00:00    1388546702
# 107455 2014-01-01 03:17:00+00:00    1388546220
# 107457 2014-01-01 03:07:05+00:00    1388545625
#
#                                                       url  objectID  \
# 70      http://krebsonsecurity.com/2014/05/true-goodby...   7814725
# 76      http://projects.aljazeera.com/2014/portrait-of...   7814608
# 91      http://www.damninteresting.com/absolute-zero-i...   7814466
# 124     http://priceonomics.com/joshua-norton-emperor-...   7814140
# ...

# %%
# clean_df = clean_df[titles]
# df = df[["Column Name","Column Name2"]]
# new_dataframe = dataframe. filter(['col_name_1', 'col_name_2'])

# %%
new_clean_df = clean_df.filter(['title'])
new_clean_df
# Out:
#                                                     title
# 70          True Goodbye: ‘Using TrueCrypt Is Not Secure’
# 76       For Hire: Dedicated Young Man With Down Syndrome
# 91                                          Absolute Zero
# 124           Joshua Norton, Emperor of the United States
# 137        The Soylent Revolution Will Not Be Pleasurable
# ...                                                   ...
# 107436  Fixing E.T. The Extra-Terrestrial for the Atar...
# 107448                              2-Stage Light Gas Gun
# 107451  Court Rules No Suspicion Needed for Laptop Sea...
# 107455  Show HN: Our little bootstrapped startup is po...
# 107457              Snapchat Phone Number Database Leaked
#
# [5978 rows x 1 columns]

# %%
def extract_titles(df, col_name):
    new_df = df. filter(['col_name'])
    return new_df

# %%
extract_titles(clean_df, 'title')
# Out:
# Empty DataFrame
# Columns: []
# Index: [70, 76, 91, 124, 137, 152, 197, 199, 205, 219, 244, 262, 269, 297, 325, 334, 394, 423, 426, 434, 446, 470, 519, 521, 554, 556, 561, 600, 638, 640, 643, 652, 716, 745, 781, 782, 785, 834, 844, 850, 920, 926, 955, 960, 1031, 1039, 1044, 1051, 1097, 1102, 1125, 1130, 1161, 1167, 1185, 1189, 1201, 1205, 1243, 1248, 1261, 1269, 1284, 1293, 1326, 1327, 1330, 1332, 1337, 1353, 1370, 1456, 1459, 1477, 1527, 1539, 1589, 1612, 1624, 1644, 1647, 1665, 1674, 1680, 1694, 1700, 1701, 1736, 1761, 1769, 1801, 1802, 1818, 1821, 1827, 1832, 1860, 1879, 1881, 1887, ...]
#
# [5978 rows x 0 columns]

# %%
def extract_titles(df, col):
    titles = df[col]
    yield (titles)

# %%
titles=extract_titles(clean_df, 'titles')
titles
# Out:
# <generator object extract_titles at 0x0000029343687040>

# %%
#cleaning titles
clean_df['title']=clean_df['title'].str.lower()

# %%
clean_df
# Out:
#                       created_at  created_at_i  \
# 70     2014-05-29 04:27:42+00:00    1401337662
# 76     2014-05-29 03:51:01+00:00    1401335461
# 91     2014-05-29 02:59:12+00:00    1401332352
# 124    2014-05-29 01:36:05+00:00    1401327365
# 137    2014-05-29 00:59:30+00:00    1401325170
# ...                          ...           ...
# 107436 2014-01-01 04:42:30+00:00    1388551350
# 107448 2014-01-01 03:34:45+00:00    1388547285
# 107451 2014-01-01 03:25:02+00:00    1388546702
# 107455 2014-01-01 03:17:00+00:00    1388546220
# 107457 2014-01-01 03:07:05+00:00    1388545625
#
#                                                       url  objectID  \
# 70      http://krebsonsecurity.com/2014/05/true-goodby...   7814725
# 76      http://projects.aljazeera.com/2014/portrait-of...   7814608
# 91      http://www.damninteresting.com/absolute-zero-i...   7814466
# 124     http://priceonomics.com/joshua-norton-emperor-...   7814140
# ...

# %%
clean_df['titles'] = clean_df['title'].str.replace('[^\w\s]','')
# Out:
# <ipython-input-60-dc6a4a41be06>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   clean_df['titles'] = clean_df['title'].str.replace('[^\w\s]','')

# %%
clean_df
# Out:
#                       created_at  created_at_i  \
# 70     2014-05-29 04:27:42+00:00    1401337662
# 76     2014-05-29 03:51:01+00:00    1401335461
# 91     2014-05-29 02:59:12+00:00    1401332352
# 124    2014-05-29 01:36:05+00:00    1401327365
# 137    2014-05-29 00:59:30+00:00    1401325170
# ...                          ...           ...
# 107436 2014-01-01 04:42:30+00:00    1388551350
# 107448 2014-01-01 03:34:45+00:00    1388547285
# 107451 2014-01-01 03:25:02+00:00    1388546702
# 107455 2014-01-01 03:17:00+00:00    1388546220
# 107457 2014-01-01 03:07:05+00:00    1388545625
#
#                                                       url  objectID  \
# 70      http://krebsonsecurity.com/2014/05/true-goodby...   7814725
# 76      http://projects.aljazeera.com/2014/portrait-of...   7814608
# 91      http://www.damninteresting.com/absolute-zero-i...   7814466
# 124     http://priceonomics.com/joshua-norton-emperor-...   7814140
# ...

# %%
def clean_titles(df, col):
    df[col]=df[col].str.lower()
    df[col] = df[col].str.replace('[^\w\s]','')
    return new_df

# %%
clean_titles(clean_df, 'titles')
# Out:
# <ipython-input-62-0c4c4c73cd41>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[col] = df[col].str.replace('[^\w\s]','')
#                   created_at  created_at_i  \
# 0       2014-05-29T08:25:40Z    1401351940
# 1       2014-05-29T08:23:46Z    1401351826
# 2       2014-05-29T08:21:56Z    1401351716
# 3       2014-05-29T08:18:42Z    1401351522
# 4       2014-05-29T08:17:30Z    1401351450
# ...                      ...           ...
# 107499  2014-01-01T00:17:03Z    1388535423
# 107500  2014-01-01T00:11:06Z    1388535066
# 107501  2014-01-01T00:06:59Z    1388534819
# 107502  2014-01-01T00:04:31Z    1388534671
# 107503  2014-01-01T00:01:00Z    1388534460
#
#                                                       url objectID  \
# 0                         https://duckduckgo.com/settings  7815290
# 1       http://bits.blogs.nytimes.com/2014/05/28/makin...  7815285
# ...

# %%
# def clean_titles(df, col):
#     df[col] = df[col].astype(str)
#     df[col] = df[col].str.replace('[{}]'.format(string.punctuation), '')
#     return df
# clean_titles(clean_df, 'title')

# %%
from stop_words import stop_words

# %%
#series = clean_df.Text.str.split(expand=True).stack().value_counts()

# %%
# from collections import Counter
# from itertools import chain

# counter = Counter(chain.from_iterable(map(str.split, clean_df.Text.tolist())))

# %%
#series = pd.Series(counter).sort_values(ascending=False)

# %%
count = clean_df['titles'].value_counts()

# %%
count
# Out:
# this week in rust                                               3
# was y combinator worth it                                       2
# implementing a jit compiled language with haskell and llvm      2
# blackphone                                                      2
# microsoft announces the surface pro 3                           2
#                                                                ..
# show hn a developersonly news site you join via pull request    1
# rip captain jerry roberts  bletchley park codebreaker           1
# rendering head in webgl                                         1
# linux difference between devconsole  devtty and devtty0         1
# technichi macbook subscription service                          1
# Name: titles, Length: 5954, dtype: int64

# %%
# count2 = clean_df.groupby(['titles']).count()
# count2

# %%
count3 = clean_df.groupby(['titles']).size()
count3
# Out:
# titles
#  92 facebook apps have access to my account                                 1
#  amazon sales take a hit in states with online tax                          1
#  apple developer indifference                                               1
#  critical crypto bug leaves linux hundreds of apps open to eavesdropping    1
#  daniels review of flash boys a wall street revolt                          1
#                                                                            ..
# zuckerberg expresses frustration over surveillance                          1
# zuckerberg musk invest in artificialintelligence company vicarious          1
# zx spectrum devs claim missing royalties from elite systems                 1
# zynga buys naturalmotion for 527m                                           1
# zynga lays off 15 of its workforce                                          1
# Length: 5954, dtype: int64

# %%
str='This is my book'
str.split()
# Out:
# ['This', 'is', 'my', 'book']

# %%
# for row in clean_df['titles']:
#     each = each
#     str.split()


#x = txt.split()

# %%
clean_df['titles']
# Out:
# 70               true goodbye using truecrypt is not secure
# 76          for hire dedicated young man with down syndrome
# 91                                            absolute zero
# 124              joshua norton emperor of the united states
# 137          the soylent revolution will not be pleasurable
#                                 ...
# 107436    fixing et the extraterrestrial for the atari 2600
# 107448                                 2stage light gas gun
# 107451    court rules no suspicion needed for laptop sea...
# 107455    show hn our little bootstrapped startup is pow...
# 107457                snapchat phone number database leaked
# Name: titles, Length: 5978, dtype: object

# %%
from stop_words import stop_words

# %%
def build_keyword_dictionary(clean_df):
    word_freq_count = {}
   
    for index, row in clean_df.iterrows():
        word_list = row['titles'].split(' ')
        for word in word_list:
            if word in word_freq_count:
                word_freq_count[word]+=1
            else:
                if word not in stop_words:
                    word_freq_count[word]=1
    return word_freq_count
        #print(index, row['titles'])

# %%
dict_count=build_keyword_dictionary(clean_df)

# %%
def build_keyword_dictionary(df, col):
    word_dictionary = {}
    for index, row in df.iterrows():
        word_list = row[col].split(' ')
        for word in word_list:
            if word in word_dictionary:
                word_dictionary[word]+=1
            else:
                if word not in stop_words:
                    word_dictionary[word]=1
    return word_dictionary

# %%
dict_count=build_keyword_dictionary(clean_df, 'titles')

# %%
sorted_dict = sorted(dict_count.items(), key=lambda x: x[1], reverse=True)[:99]
for i in sorted_dict:
    print(i[0], i[1])
# Out:
#  535
# new 185
# google 167
# bitcoin 101
# open 93
# programming 90
# web 89
# data 86
# video 79
# python 75
# facebook 72
# code 72
# using 71
# released 71
# 2013 65
# javascript 65
# free 64
# game 64
# source 64
# internet 63
# microsoft 59
# linux 59
# c 59
# app 58
# dont 57
# pdf 55
# work 54
# language 54
# software 52
# 2014 52
# startup 51
# apple 50
# use 50
# make 50
# time 48
# yc 48
# security 48
# nsa 45
# github 45
# windows 44
# 1 41
# world 41
# way 41
# like 41
# heartbleed 41
# project 40
# computer 40
# git 37
# users 37
# twitter 37
# design 37
# ios 37
# developer 36
# os 36
# ceo 36
# vs 36
# big 36
# life 36
# day 35
# android 34
# simple 34
# online 34
# years 33
# court 33
# guide 32
# learning 32
# mt 32
# api 32
# says 32
# apps 32
# browser 32
# server 31
# firefox 31
# fast 31
# gox 31
# problem 31
# mozilla 31
# engine 31
# site 31
# introducing 30
# amazon 30
# year 30
# support 29
# stop 29
# built 29
# better 29
# million 29
# people 29
# text 29
# ...

# %%
def sort_dict(df):
    sorted_dict = sorted(dict_count.items(), key=lambda x: x[1], reverse=True)[:99]
    for i in sorted_dict:
        print(i[0], i[1])

# %%
sort_dict(clean_df)
# Out:
#  535
# new 185
# google 167
# bitcoin 101
# open 93
# programming 90
# web 89
# data 86
# video 79
# python 75
# facebook 72
# code 72
# using 71
# released 71
# 2013 65
# javascript 65
# free 64
# game 64
# source 64
# internet 63
# microsoft 59
# linux 59
# c 59
# app 58
# dont 57
# pdf 55
# work 54
# language 54
# software 52
# 2014 52
# startup 51
# apple 50
# use 50
# make 50
# time 48
# yc 48
# security 48
# nsa 45
# github 45
# windows 44
# 1 41
# world 41
# way 41
# like 41
# heartbleed 41
# project 40
# computer 40
# git 37
# users 37
# twitter 37
# design 37
# ios 37
# developer 36
# os 36
# ceo 36
# vs 36
# big 36
# life 36
# day 35
# android 34
# simple 34
# online 34
# years 33
# court 33
# guide 32
# learning 32
# mt 32
# api 32
# says 32
# apps 32
# browser 32
# server 31
# firefox 31
# fast 31
# gox 31
# problem 31
# mozilla 31
# engine 31
# site 31
# introducing 30
# amazon 30
# year 30
# support 29
# stop 29
# built 29
# better 29
# million 29
# people 29
# text 29
# ...

# %%
#tuple_list = list(sorted_dict.items())

# %%
def convert(list):
    return tuple(list)
list = [1, 2, 3, 4]
print(convert(list))
# Out:
# (1, 2, 3, 4)

# %%
def convert(sorted_dict):
    return tuple(sorted_dict)

# %%
convert(sorted_dict)
# Out:
# (('', 535),
#  ('new', 185),
#  ('google', 167),
#  ('bitcoin', 101),
#  ('open', 93),
#  ('programming', 90),
#  ('web', 89),
#  ('data', 86),
#  ('video', 79),
#  ('python', 75),
#  ('facebook', 72),
#  ('code', 72),
#  ('using', 71),
#  ('released', 71),
#  ('2013', 65),
#  ('javascript', 65),
#  ('free', 64),
#  ('game', 64),
#  ('source', 64),
#  ('internet', 63),
#  ('microsoft', 59),
#  ('linux', 59),
#  ('c', 59),
#  ('app', 58),
#  ('dont', 57),
#  ('pdf', 55),
#  ('work', 54),
#  ('language', 54),
#  ('software', 52),
#  ('2014', 52),
#  ('startup', 51),
#  ('apple', 50),
#  ('use', 50),
#  ('make', 50),
#  ('time', 48),
#  ('yc', 48),
#  ('security', 48),
#  ('nsa', 45),
#  ('github', 45),
#  ('windows', 44),
#  ('1', 41),
#  ('world', 41),
#  ('way', 41),
#  ('like', 41),
#  ('heartbleed', 41),
#  ('project', 40),
#  ('computer', 40),
#  ('git', 37),
#  ('users', 37),
#  ('twitter', 37),
#  ('design', 37),
#  ('ios', 37),
#  ('developer', 36),
#  ('os', 36),
# ...

# %%
#pipeline is a list of lists.  list is a structure that is defined, it's a structure that is set and we can index it and can reference it that way. 
#this takes less memory as a json than a proper DF.
